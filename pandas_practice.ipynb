# %%
import pandas as pd

# %%
color=pd.Series(["red","green","yellow"])

# %%
color
# Out:
# 0       red
# 1     green
# 2    yellow
# dtype: object

# %%
car=pd.Series(["polo ","jimny ","fortuner "]);car
# Out:
# 0        polo
# 1       jimny
# 2    fortuner
# dtype: object

# %%
both1=car+color
both2=pd.concat([car,color])
#both2=pd.concat([car,color],ignore_index=True)

# %%
both1,both2
# Out:
# (0           polo red
#  1        jimny green
#  2    fortuner yellow
#  dtype: object,
#  0        polo
#  1       jimny
#  2    fortuner
#  0          red
#  1        green
#  2       yellow
#  dtype: object)

# %%
df=pd.read_csv("C:\\Users\\amogh\\Music\\ArtMac\\54 - car-sales.csv");df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.to_csv("the_car.csv")

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
num=pd.Series([1,2,3,4])
print(num.mean())
num.sum()
# Out:
# 2.5
# 10

# %%
df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
print(df.count)
len(df)
# Out:
# <bound method DataFrame.count of      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00>
# 10

# %%
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
df.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df.loc[3] #==df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
df["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
df["Odometer (KM)"]>100000
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Odometer (KM), dtype: bool

# %%
pd.crosstab(df.Make,df.Doors)
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
df.groupby('Make').mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
df.groupby('Doors').mean(numeric_only=True)
# Out:
#        Odometer (KM)
# Doors
# 3           32549.00
# 4           92785.75
# 5           11179.00

# %%
df["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
df["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(df['Odometer (KM)'])
plt.scatter(df.index, df['Odometer (KM)'])

# %%
plt.xlabel('Index')
plt.ylabel('Odometer Reading')
plt.title('Car Odometer Readings')
plt.show()

# %%
df['Price'] = df['Price'].str.replace('[$,]', '', regex=True).astype(float);df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
df['Price'] = df['Price'].str.replace('[.0]', ' ');
df['Price'] = df['Price'].str.replace(',','')
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
df['Price']=df['Price'].astype(int);df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
df['Make']=df['Make'].str.lower();df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
df=pd.read_csv("C:\\Users\\amogh\\Music\\ArtMac\\51 - car-sales-extended-missing-data.csv")

# %%
df.sample(frac=0.01)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 768   Honda   Blue       217068.0    4.0   4358.0
# 713  Toyota    Red       185940.0    4.0   9685.0
# 785   Honda  White       178351.0    4.0  14331.0
# 811     BMW  White        83309.0    5.0  45509.0
# 679  Toyota    Red       248634.0    NaN   9919.0
# 142   Honda  White        21393.0    4.0  20490.0
# 710  Nissan  White       177272.0    4.0  18248.0
# 687   Honda  Black       232910.0    4.0   6690.0
# 924  Nissan    Red       113278.0    3.0  15666.0
# 559  Toyota   Blue       220679.0    4.0  15508.0

# %%
len(df)
# Out:
# 1000

# %%
df.dtypes
# Out:
# Make              object
# Colour            object
# Odometer (KM)    float64
# Doors            float64
# Price            float64
# dtype: object

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
df['Doors']=df['Doors'].fillna(df['Doors'].mean())
df.sample(frac=0.01)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 846  Toyota  White        93593.0    4.0  29638.0
# 715  Toyota  White            NaN    4.0  23844.0
# 947  Toyota   Blue        17609.0    4.0      NaN
# 109   Honda   Blue       219217.0    4.0   4747.0
# 50   Toyota    Red       184878.0    4.0   7445.0
# 369     NaN  White       133069.0    3.0   5008.0
# 472  Toyota  White       172018.0    4.0  10196.0
# 213   Honda  Green       238825.0    4.0   9530.0
# 291   Honda    Red        11035.0    4.0  10602.0
# 572  Toyota  White       185455.0    4.0  16220.0

# %%
df=df.dropna()

# %%
len(df)
df.sample(frac=0.01)
# Out:
#        Make Colour  Odometer (KM)     Doors    Price
# 383   Honda  White       144088.0  4.000000   5838.0
# 264  Toyota  White        59222.0  4.000000  32676.0
# 516  Toyota    Red        68125.0  4.000000   8105.0
# 638  Toyota    Red        49807.0  4.000000  25775.0
# 893  Toyota  White       248815.0  4.000000   9785.0
# 910  Nissan  White        40598.0  4.000000  24122.0
# 707  Nissan  White       222917.0  4.000000  15673.0
# 607  Toyota   Blue       149270.0  4.011579  21953.0

# %%
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0      5
# 1       BMW   Blue       192714.0    5.0  19943.0      5
# 2     Honda  White        84714.0    4.0  28343.0      5
# 3    Toyota  White       154365.0    4.0  13434.0      5
# 4    Nissan   Blue       181577.0    3.0  14043.0      5
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5
# 995  Toyota  Black        35820.0    4.0  32042.0      5
# 997  Nissan   Blue        66604.0    4.0  31570.0      5
# 998   Honda  White       215883.0    4.0   4001.0      5
# 999  Toyota   Blue       248360.0    4.0  12732.0      5
#
# [815 rows x 6 columns]

# %%
df=df.drop("Seats",axis=1)

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 994     BMW   Blue       163322.0    3.0  31666.0
# 995  Toyota  Black        35820.0    4.0  32042.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [815 rows x 5 columns]

# %%
df['Seats']=5

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0      5
# 1       BMW   Blue       192714.0    5.0  19943.0      5
# 2     Honda  White        84714.0    4.0  28343.0      5
# 3    Toyota  White       154365.0    4.0  13434.0      5
# 4    Nissan   Blue       181577.0    3.0  14043.0      5
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5
# 995  Toyota  Black        35820.0    4.0  32042.0      5
# 997  Nissan   Blue        66604.0    4.0  31570.0      5
# 998   Honda  White       215883.0    4.0   4001.0      5
# 999  Toyota   Blue       248360.0    4.0  12732.0      5
#
# [815 rows x 6 columns]

# %%
df['car_price']=df['Price']/df['Odometer (KM)']

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  car_price
# 0     Honda  White        35431.0    4.0  15323.0      5   0.432474
# 1       BMW   Blue       192714.0    5.0  19943.0      5   0.103485
# 2     Honda  White        84714.0    4.0  28343.0      5   0.334573
# 3    Toyota  White       154365.0    4.0  13434.0      5   0.087027
# 4    Nissan   Blue       181577.0    3.0  14043.0      5   0.077339
# ..      ...    ...            ...    ...      ...    ...        ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5   0.193887
# 995  Toyota  Black        35820.0    4.0  32042.0      5   0.894528
# 997  Nissan   Blue        66604.0    4.0  31570.0      5   0.473996
# 998   Honda  White       215883.0    4.0   4001.0      5   0.018533
# 999  Toyota   Blue       248360.0    4.0  12732.0      5   0.051264
#
# [815 rows x 7 columns]

# %%
df.drop('car_price',axis=1)
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0      5
# 1       BMW   Blue       192714.0    5.0  19943.0      5
# 2     Honda  White        84714.0    4.0  28343.0      5
# 3    Toyota  White       154365.0    4.0  13434.0      5
# 4    Nissan   Blue       181577.0    3.0  14043.0      5
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5
# 995  Toyota  Black        35820.0    4.0  32042.0      5
# 997  Nissan   Blue        66604.0    4.0  31570.0      5
# 998   Honda  White       215883.0    4.0   4001.0      5
# 999  Toyota   Blue       248360.0    4.0  12732.0      5
#
# [815 rows x 6 columns]

# %%
df=df.sample(frac=1)

# %%
df
# Out:
#        Make Colour  Odometer (KM)     Doors    Price  Seats  car_price
# 332  Nissan   Blue       195494.0  4.000000   6460.0      5   0.033044
# 51    Honda  White       161068.0  4.011579  13698.0      5   0.085045
# 243  Nissan  Green       189739.0  4.000000  16730.0      5   0.088174
# 541  Toyota  Black       218253.0  4.000000  13176.0      5   0.060370
# 27    Honda  Green        82783.0  4.000000  10984.0      5   0.132684
# ..      ...    ...            ...       ...      ...    ...        ...
# 492  Toyota  White        66150.0  4.000000  25111.0      5   0.379607
# 108  Nissan   Blue       129769.0  3.000000  15617.0      5   0.120345
# 981  Toyota  White       129454.0  4.000000   6446.0      5   0.049794
# 709     BMW   Blue       134103.0  5.000000  36109.0      5   0.269263
# 942  Nissan   Blue       228192.0  4.000000  12641.0      5   0.055396
#
# [815 rows x 7 columns]

# %%
df.reset_index()
# Out:
#      index    Make Colour  Odometer (KM)     Doors    Price  Seats  car_price
# 0      332  Nissan   Blue       195494.0  4.000000   6460.0      5   0.033044
# 1       51   Honda  White       161068.0  4.011579  13698.0      5   0.085045
# 2      243  Nissan  Green       189739.0  4.000000  16730.0      5   0.088174
# 3      541  Toyota  Black       218253.0  4.000000  13176.0      5   0.060370
# 4       27   Honda  Green        82783.0  4.000000  10984.0      5   0.132684
# ..     ...     ...    ...            ...       ...      ...    ...        ...
# 810    492  Toyota  White        66150.0  4.000000  25111.0      5   0.379607
# 811    108  Nissan   Blue       129769.0  3.000000  15617.0      5   0.120345
# 812    981  Toyota  White       129454.0  4.000000   6446.0      5   0.049794
# 813    709     BMW   Blue       134103.0  5.000000  36109.0      5   0.269263
# 814    942  Nissan   Blue       228192.0  4.000000  12641.0      5   0.055396
#
# [815 rows x 8 columns]

# %%
df
# Out:
#        Make Colour  Odometer (KM)     Doors    Price  Seats  car_price
# 332  Nissan   Blue       195494.0  4.000000   6460.0      5   0.033044
# 51    Honda  White       161068.0  4.011579  13698.0      5   0.085045
# 243  Nissan  Green       189739.0  4.000000  16730.0      5   0.088174
# 541  Toyota  Black       218253.0  4.000000  13176.0      5   0.060370
# 27    Honda  Green        82783.0  4.000000  10984.0      5   0.132684
# ..      ...    ...            ...       ...      ...    ...        ...
# 492  Toyota  White        66150.0  4.000000  25111.0      5   0.379607
# 108  Nissan   Blue       129769.0  3.000000  15617.0      5   0.120345
# 981  Toyota  White       129454.0  4.000000   6446.0      5   0.049794
# 709     BMW   Blue       134103.0  5.000000  36109.0      5   0.269263
# 942  Nissan   Blue       228192.0  4.000000  12641.0      5   0.055396
#
# [815 rows x 7 columns]
